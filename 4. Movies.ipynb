# %%
import seaborn as sns
import matplotlib.pyplot as plt
import  numpy as nm
import pandas as pd
import matplotlib as mpl

# %%
movies=pd.read_csv('C:/Users/Administrator/Documents/tmdb_5000_movies.csv')
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %% [markdown]
# # Draw a correlation of movies dataset ignore the id column

# %%
m=movies.drop(columns='id')
m.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage  \
# 0                   http://www.avatarmovie.com/
# 1  http://disney.go.com/disneypictures/pirates/
# 2   http://www.sonypictures.com/movies/spectre/
# 3            http://www.thedarkknightrises.com/
# 4          http://movies.disney.com/john-carter
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
m.describe()
# Out:
#              budget   popularity       revenue      runtime  vote_average  \
# count  4.803000e+03  4803.000000  4.803000e+03  4801.000000   4803.000000
# mean   2.904504e+07    21.492301  8.226064e+07   106.875859      6.092172
# std    4.072239e+07    31.816650  1.628571e+08    22.611935      1.194612
# min    0.000000e+00     0.000000  0.000000e+00     0.000000      0.000000
# 25%    7.900000e+05     4.668070  0.000000e+00    94.000000      5.600000
# 50%    1.500000e+07    12.921594  1.917000e+07   103.000000      6.200000
# 75%    4.000000e+07    28.313505  9.291719e+07   118.000000      6.800000
# max    3.800000e+08   875.581305  2.787965e+09   338.000000     10.000000
#
#          vote_count
# count   4803.000000
# mean     690.217989
# std     1234.585891
# min        0.000000
# 25%       54.000000
# 50%      235.000000
# 75%      737.000000
# max    13752.000000

# %%
m.corr()
# Out:
#                 budget  popularity   revenue   runtime  vote_average  \
# budget        1.000000    0.505414  0.730823  0.269851      0.093146
# popularity    0.505414    1.000000  0.644724  0.225502      0.273952
# revenue       0.730823    0.644724  1.000000  0.251093      0.197150
# runtime       0.269851    0.225502  0.251093  1.000000      0.375046
# vote_average  0.093146    0.273952  0.197150  0.375046      1.000000
# vote_count    0.593180    0.778130  0.781487  0.271944      0.312997
#
#               vote_count
# budget          0.593180
# popularity      0.778130
# revenue         0.781487
# runtime         0.271944
# vote_average    0.312997
# vote_count      1.000000

# %%
m.corr()
sns.heatmap(m.corr(),annot=True,cmap='hsv')
plt.show()

# %%
draw a cluster map of corr

# %%
m.corr()
sns.clustermap(m.corr(),annot=True,cmap='hsv')
plt.show()

# %% [markdown]
# ###### show top 10 movies based on popularity whose vote_average is between
# #a) 4 to 6
# #b) 6 to 8
# #c) 8 to 10

# %%
m.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage  \
# 0                   http://www.avatarmovie.com/
# 1  http://disney.go.com/disneypictures/pirates/
# 2   http://www.sonypictures.com/movies/spectre/
# 3            http://www.thedarkknightrises.com/
# 4          http://movies.disney.com/john-carter
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
m[['vote_average']]
# Out:
#       vote_average
# 0              7.2
# 1              6.9
# 2              6.3
# 3              7.6
# 4              6.1
# 5              5.9
# 6              7.4
# 7              7.3
# 8              7.4
# 9              5.7
# 10             5.4
# 11             6.1
# 12             7.0
# 13             5.9
# 14             6.5
# 15             6.3
# 16             7.4
# 17             6.4
# 18             6.2
# 19             7.1
# 20             6.5
# 21             6.2
# 22             7.6
# 23             5.8
# 24             6.6
# 25             7.5
# 26             7.1
# 27             5.5
# 28             6.5
# 29             6.9
# ...            ...
# 4773           7.4
# 4774           6.0
# 4775           6.3
# 4776           6.8
# 4777           5.5
# 4778           6.0
# 4779           6.4
# 4780           0.0
# 4781           6.0
# 4782           6.8
# 4783           4.7
# 4784           6.2
# 4785           0.0
# 4786           5.6
# 4787           4.2
# ...

# %%
m[m.vote_average == 4:6]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-639b1abfce2e> in <module>()
# ----> 1 m[m.vote_average == 4:6]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2674
#    2675         # see if we can slice the rows
# -> 2676         indexer = convert_to_index_sliceable(self, key)
#    2677         if indexer is not None:
#    2678             return self._getitem_slice(indexer)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2324     idx = obj.index
#    2325     if isinstance(key, slice):
# -> 2326         return idx._convert_slice_indexer(key, kind='getitem')
#    2327
#    2328     elif isinstance(key, compat.string_types):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _convert_slice_indexer(self, key, kind)
#    1724             """
# ...
